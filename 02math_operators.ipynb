# %% [markdown]
# <a href="https://colab.research.google.com/github/adi-bhagat20/python/blob/main/math_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2 + 3
# Out:
# 5

# %%
9 - 3
# Out:
# 6

# %%
0 = 9
# Out:
#   File "/tmp/ipykernel_1190/3411711250.py", line 1
#     0 = 9
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
12*8
# Out:
# 96

# %%
12/3
# Out:
# 4.0

# %%
12//3
# Out:
# 4

# %%
15/4
# Out:
# 3.75

# %%
15//4
# Out:
# 3

# %%
2**3
# Out:
# 8

# %%
13%3
# Out:
# 1
